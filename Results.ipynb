# %%
import pandas as pd

# %%
results = pd.read_csv('Results/results.csv', index_col='id_num')

# %% [markdown]
# ### Direct Free Kick Shots:

# %%
direct_results = results[results['dataset']=='direct']

direct_results.sort_values('val_mean', ascending=False)
# Out:
#         calibration dataset              model_type  \
# id_num
# 1                 0  direct      LogisticRegression
# 3                 0  direct      LogisticRegression
# 5                 0  direct      LogisticRegression
# 7                 0  direct  RandomForestClassifier
# 9                 0  direct  RandomForestClassifier
# 11                0  direct  RandomForestClassifier
# 6                 1  direct      LogisticRegression
# 4                 1  direct      LogisticRegression
# 2                 1  direct      LogisticRegression
# 8                 1  direct  RandomForestClassifier
# 10                1  direct  RandomForestClassifier
# 12                1  direct  RandomForestClassifier
#
#                                                    params  train_mean  \
# id_num
# 1       {'logisticregression__C': 0.07017038286703826,...    0.626854
# 3       {'logisticregression__C': 0.9426684551178854, ...    0.626890
# ...

# %% [markdown]
# ### Head Cross Shots:

# %%
head_cross_results = results[results['dataset']=='head_cross']

head_cross_results.sort_values('val_mean', ascending=False)
# Out:
#         calibration     dataset              model_type  \
# id_num
# 13                0  head_cross      LogisticRegression
# 15                0  head_cross      LogisticRegression
# 17                0  head_cross      LogisticRegression
# 14                1  head_cross      LogisticRegression
# 16                1  head_cross      LogisticRegression
# 18                1  head_cross      LogisticRegression
# 19                0  head_cross  RandomForestClassifier
# 20                1  head_cross  RandomForestClassifier
# 21                0  head_cross  RandomForestClassifier
# 23                0  head_cross  RandomForestClassifier
# 22                1  head_cross  RandomForestClassifier
# 24                1  head_cross  RandomForestClassifier
#
#                                                    params  train_mean  \
# id_num
# 13      {'logisticregression__C': 0.003257020655659782...    0.781580
# 15      {'logisticregression__C': 0.005223345074266843...    0.781611
# ...

# %% [markdown]
# ### Cross Shots:

# %%
cross_results = results[results['dataset']=='cross']

cross_results.sort_values('val_mean', ascending=False)
# Out:
#         calibration dataset              model_type  \
# id_num
# 25                0   cross      LogisticRegression
# 27                0   cross      LogisticRegression
# 29                0   cross      LogisticRegression
# 31                0   cross  RandomForestClassifier
# 33                0   cross  RandomForestClassifier
# 35                0   cross  RandomForestClassifier
# 26                1   cross      LogisticRegression
# 28                1   cross      LogisticRegression
# 30                1   cross      LogisticRegression
# 32                1   cross  RandomForestClassifier
# 34                1   cross  RandomForestClassifier
# 36                1   cross  RandomForestClassifier
#
#                                                    params  train_mean  \
# id_num
# 25      {'logisticregression__C': 1.9144819761699576, ...    0.799152
# 27      {'logisticregression__C': 7.896522868499725, '...    0.799155
# ...

# %% [markdown]
# ### Head Shots:

# %%
head_results = results[results['dataset']=='head']

head_results.sort_values('val_mean', ascending=False)
# Out:
#         calibration dataset              model_type  \
# id_num
# 43                0    head  RandomForestClassifier
# 45                0    head  RandomForestClassifier
# 47                0    head  RandomForestClassifier
# 44                1    head  RandomForestClassifier
# 46                1    head  RandomForestClassifier
# 48                1    head  RandomForestClassifier
# 37                0    head      LogisticRegression
# 39                0    head      LogisticRegression
# 41                0    head      LogisticRegression
# 38                1    head      LogisticRegression
# 40                1    head      LogisticRegression
# 42                1    head      LogisticRegression
#
#                                                    params  train_mean  \
# id_num
# 43      {'randomforestclassifier__n_estimators': 2000,...    0.953555
# 45      {'randomforestclassifier__n_estimators': 1800,...    0.937684
# ...

# %% [markdown]
# # Regular Shots:

# %%
regular_results = results[results['dataset']=='regular']

regular_results.sort_values('val_mean', ascending=False)
# Out:
#         calibration  dataset              model_type  \
# id_num
# 55                0  regular  RandomForestClassifier
# 57                0  regular  RandomForestClassifier
# 56                1  regular  RandomForestClassifier
# 58                1  regular  RandomForestClassifier
# 60                1  regular  RandomForestClassifier
# 59                0  regular  RandomForestClassifier
# 52                1  regular      LogisticRegression
# 50                1  regular      LogisticRegression
# 54                1  regular      LogisticRegression
# 49                0  regular      LogisticRegression
# 51                0  regular      LogisticRegression
# 53                0  regular      LogisticRegression
#
#                                                    params  train_mean  \
# id_num
# 55      {'randomforestclassifier__n_estimators': 1400,...    0.868935
# 57      {'randomforestclassifier__n_estimators': 1400,...    0.868101
# ...
